# %% [markdown]
# <a href="https://colab.research.google.com/github/wyenaa/235150700111019_wyenasuilianty_percobaan10/blob/main/weather_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center><font size="6">The Clash of Classifiers</font></center></h1>
#
# <h2><center><font size="5">Where Classifiers Clash, Intelligence Reigns!</font></center></h2>
#
#
# <br>
#
#
# Created by:
# Tirana Noor Fatyanosa

# %% [markdown]
# # <a id='intro'>Introduction</a>
#
# Kernel ini akan memandu Anda melalui proses **analisis data**, pembuatan **model dasar (baseline model)**, dan, pada akhirnya, **pengajuan (submission)** solusi terbaik yang ditemukan.
#
# Dataset yang digunakan dalam tutorial ini adalah dataset **Klasifikasi Jenis Cuaca**.

# %% [markdown]
# # <a id='create-kaggle'>Buat Akun Kaggle</a>
#
# Sebelum memulai, kita perlu melakukan beberapa persiapan. Yang pertama adalah membuat akun Kaggle.
#
# ### **Langkah 1: Buat Akun Kaggle**
# Kunjungi halaman utama Kaggle:
#
# [https://www.kaggle.com/](https://www.kaggle.com/)
#
# ### **Langkah 2: Daftar**
# Klik tombol **"Register"** di pojok kanan atas halaman.
#
# Anda akan memiliki beberapa opsi untuk mendaftar:
# - Daftar dengan **Google**
# - Daftar dengan **Facebook**
# - Daftar dengan **Email**

# %% [markdown]
# # <a id='join'>Bergabung dalam Kompetisi</a>
#
# ### **Langkah 1: Masuk ke Halaman Kompetisi**
# Kunjungi tautan berikut:
#
# [https://bit.ly/klasifikasicuaca](https://bit.ly/klasifikasicuaca)
#
# ### **Langkah 2: Bergabung dengan Kompetisi**
# Sekarang, Anda dapat bergabung dalam kompetisi dengan mengklik tautan **"Join Competition"**.
# Jika Anda setuju dengan aturan kompetisi, klik tombol **"I Understand and Accept"** di bagian atas halaman.
#
# ![](https://i.imgur.com/8DQjFuN.png)

# %% [markdown]
# # <a id='create-import'>Buat dan Impor Notebook</a>
#
# ### **Langkah 1: Buat Notebook Baru**
# Masuk ke tab **Code** dan buat notebook baru untuk bekerja dengan data menggunakan tombol **"New Notebook"**.
# (Jika Anda mengklik tombol ini sebelum menerima aturan kompetisi, Anda akan diminta untuk membaca dan menyetujui aturan terlebih dahulu.)
#
# ![](https://i.imgur.com/CD8DRYq.png)
#
# ### **Langkah 2: Unduh Contoh Notebook**
# Unduh notebook dari tautan berikut.
#
# ### **Langkah 3: Impor Notebook**
# Buka menu **File**, lalu klik **Import Notebook** → Pilih file **.ipynb** dari perangkat Anda dan unggah.

# %% [markdown]
# # <a id='data-prep'>Persiapan Data</a>

# %% [markdown]
# ## <a id='22'>Muat Data</a>
#
# Terdapat data **train** dan **test**, serta sebuah file contoh **submission**.
#
# Mari kita muat data **train** dan **test**.

# %% [markdown]
# ![image.png](attachment:448d86d7-6064-463f-a97e-34231268f43d.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
import pandas as pd

train = pd.read_csv("/content/train.csv")
test = pd.read_csv("/content/test.csv")

# %% [markdown]
# # <a id='explore'>Eksplorasi Data</a>
#
# Kita memeriksa bentuk (shape) dari dataframe **train** dan **test**, serta menampilkan beberapa baris data untuk mendapatkan gambaran awal tentang dataset.

# %% [markdown]
# ![image.png](attachment:36997f2f-7517-42cf-851a-91087502b7eb.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
train.sample(5).head()
# Out:
#         ID  Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 7450  7450          -16        75        12.0                 62
# 4125  4125          -10        81         2.0                 98
# 8795  8795           11        77         5.5                 13
# 1488  1488           27        61         2.5                 51
# 816    816           17        73        17.5                 93
#
#         Cloud Cover  Atmospheric Pressure  UV Index  Season  Visibility (km)  \
# 7450  partly cloudy                984.82         1  Summer             14.5
# 4125       overcast                998.06         1  Winter              3.0
# 8795  partly cloudy               1006.35         2  Summer              5.5
# 1488         cloudy               1045.38         4  Summer              7.0
# 816        overcast               1003.31         1  Winter              3.0
#
#       Location Weather Type
# 7450   coastal        Rainy
# 4125  mountain        Snowy
# ...

# %% [markdown]
# ![image.png](attachment:2ef135ef-21e3-4cfa-8622-705ca0cd990f.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
test.sample(5).head()
# Out:
#          ID  Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 2716  11956           -4        95         3.5                 77
# 876   10116           72        83        39.5                 88
# 2152  11392           28        71        15.5                 89
# 1188  10428            4        77        19.5                 99
# 2302  11542           35        94        30.5                 81
#
#         Cloud Cover  Atmospheric Pressure  UV Index  Season  Visibility (km)  \
# 2716       overcast                987.80         0  Winter              3.0
# 876        overcast                992.93        12  Autumn              4.5
# 2152  partly cloudy               1006.55        10  Spring              5.0
# 1188       overcast                991.95         0  Winter              4.5
# 2302  partly cloudy               1018.53         7  Winter              3.5
#
#       Location
# 2716  mountain
# 876    coastal
# 2152    inland
# 1188    inland
# 2302   coastal

# %% [markdown]
# ![image.png](attachment:5c34c867-b77e-46f3-894a-e730d2c782f1.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
print("Train: rows:{} cols:{}".format(train.shape[0], train.shape[1]))
print("Test: rows:{} cols:{}".format(test.shape[0], test.shape[1]))
# Out:
# Train: rows:9240 cols:12
# Test: rows:3960 cols:11

# %% [markdown]
# Baik file **train** maupun **test** masing-masing memiliki 10 fitur.
#
# Data **train** juga memiliki nilai target, yaitu **Weather Type**.
#
# Sebelum membuat model, penting untuk memahami data dengan baik. Oleh karena itu, kita akan mengeksplorasi berbagai fitur yang tersedia.

# %% [markdown]
# ![image.png](attachment:fe86bf8e-35dd-4e1d-b797-edd71696262c.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    9240 non-null   int64
#  1   Temperature           9240 non-null   int64
#  2   Humidity              9240 non-null   int64
#  3   Wind Speed            9240 non-null   float64
#  4   Precipitation (%)     9240 non-null   int64
#  5   Cloud Cover           9240 non-null   object
#  6   Atmospheric Pressure  9240 non-null   float64
#  7   UV Index              9240 non-null   int64
#  8   Season                9240 non-null   object
#  9   Visibility (km)       9240 non-null   float64
#  10  Location              9240 non-null   object
#  11  Weather Type          9240 non-null   object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 866.4+ KB

# %% [markdown]
# ![image.png](attachment:a5454cfa-5c55-4339-88c0-0b3104fb162f.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
train.describe()
# Out:
#                 ID  Temperature     Humidity   Wind Speed  Precipitation (%)  \
# count  9240.000000  9240.000000  9240.000000  9240.000000        9240.000000
# mean   4619.500000    19.023810    68.481602     9.770563          53.434416
# std    2667.502577    17.342262    20.168982     6.867376          32.082985
# min       0.000000   -25.000000    20.000000     0.000000           0.000000
# 25%    2309.750000     4.000000    57.000000     5.000000          19.000000
# 50%    4619.500000    21.000000    70.000000     8.500000          58.000000
# 75%    6929.250000    31.000000    83.000000    13.500000          82.000000
# max    9239.000000   109.000000   109.000000    47.500000         109.000000
#
#        Atmospheric Pressure     UV Index  Visibility (km)
# count           9240.000000  9240.000000      9240.000000
# mean            1005.637922     3.996753         5.448864
# std               36.576965     3.857342         3.308695
# ...

# %% [markdown]
# ## <a id='missing'>Periksa Data yang Hilang</a>
#
# Mari kita buat sebuah fungsi untuk memeriksa apakah ada data yang hilang

# %% [markdown]
# ![image.png](attachment:9c2480d5-2aa3-4048-93c7-f23fe50848f2.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_data(train)
# Out:
#                       Total  Percent
# ID                        0      0.0
# Temperature               0      0.0
# Humidity                  0      0.0
# Wind Speed                0      0.0
# Precipitation (%)         0      0.0
# Cloud Cover               0      0.0
# Atmospheric Pressure      0      0.0
# UV Index                  0      0.0
# Season                    0      0.0
# Visibility (km)           0      0.0
# Location                  0      0.0
# Weather Type              0      0.0

# %% [markdown]
# ![image.png](attachment:3160cb14-290d-4cd5-8b55-c59ce51c45c1.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
missing_data(test)
# Out:
#                       Total  Percent
# ID                        0      0.0
# Temperature               0      0.0
# Humidity                  0      0.0
# Wind Speed                0      0.0
# Precipitation (%)         0      0.0
# Cloud Cover               0      0.0
# Atmospheric Pressure      0      0.0
# UV Index                  0      0.0
# Season                    0      0.0
# Visibility (km)           0      0.0
# Location                  0      0.0

# %% [markdown]
# Baik dalam dataset **train** maupun **test**, tidak ada data yang hilang.

# %% [markdown]
# # <a id='preprocess'>Praproses Data</a>
# Konversi data kategorikal menjadi numerik.

# %% [markdown]
# ![image.png](attachment:8ffee2d8-8a0f-419b-a7e4-726cec144e3c.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
cat_columns = train.select_dtypes(['object']).columns
train[cat_columns] = train[cat_columns].astype('category')
train[cat_columns] = train[cat_columns].apply(lambda x:x.cat.codes)

# %% [markdown]
# ![image.png](attachment:14752629-2d84-4ab7-ac0d-efe375f139d4.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
cat_columns = test.select_dtypes(['object']).columns
test[cat_columns] = test[cat_columns].astype('category')
test[cat_columns] = test[cat_columns].apply(lambda x:x.cat.codes)

# %% [markdown]
# # <a id='model'>Bangun Model Prediktif</a>
#
# Mari kita mulai dengan pembuatan model prediktif. Kita akan membuat model yang sangat sederhana sebagai langkah awal.

# %% [markdown]
# ## <a id='split'>Pisahkan Data</a>
#
# Mari kita bagi dataset menjadi set **pelatihan** (train) dan **validasi** (valid). Kita akan menggunakan pembagian **80-20**.
# Selain itu, kita juga akan menetapkan matriks untuk pelatihan dan validasi serta vektor dengan nilai target.

# %% [markdown]
# ![image.png](attachment:ed60e1f9-984d-4f70-b774-ae571c72ee63.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

from sklearn.model_selection import train_test_split

train, valid = train_test_split(train, shuffle=True)

# %% [markdown]
# ## <a id='baseline'>Buat Model Dasar (Baseline Model)</a>

# %% [markdown]
# ![image.png](attachment:334b2a9d-c495-4409-82e7-7821fef61dd3.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan


target = 'Weather Type'
train_Y = train[target].values
train_X = train.drop(target,axis=1)

valid_Y = valid[target].values
valid_X = valid.drop(target,axis=1)

# %% [markdown]
# Mari kita siapkan model sederhana menggunakan **Naive Bayes**.
#
# Naïve Bayes juga dikenal sebagai **klasifikator probabilistik** karena didasarkan pada **Teorema Bayes**.
# Naïve Bayes adalah klasifikator berbasis probabilitas yang mengasumsikan bahwa setiap fitur bersifat independen satu sama lain (oleh karena itu disebut 'naïve').
#
# Model ini menghitung probabilitas bahwa suatu data termasuk dalam kelas tertentu berdasarkan nilai fitur-fiturnya.
# Naïve Bayes dapat diibaratkan sebagai "penebak cerdas" yang menggunakan data sebelumnya untuk memprediksi hasil di masa depan, berdasarkan prinsip:
# *"Jika diberikan kondisi ini, berapa kemungkinan terjadinya kondisi itu?"*

# %% [markdown]
# ![image.png](attachment:8cc714f1-06eb-41e9-a0bc-b6cd5f8942fd.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB(var_smoothing=1e-09)

# %% [markdown]
# Selanjutnya, kita melatih (fit) klasifikator dengan data pelatihan yang telah disiapkan sebelumnya.

# %% [markdown]
# ![image.png](attachment:84f83174-4826-4a8b-8fa7-bd4ea2f66a44.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

gnb.fit(train_X, train_Y)
# Out:
# GaussianNB()

# %% [markdown]
# ![image.png](attachment:713a9c3c-24c0-4fb9-b690-d9ede85a3c0a.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

pred = gnb.predict(valid_X)

# %% [markdown]
# ## <a id='52'>Evaluasi Model</a>
#
# Mari kita evaluasi kinerja model.
#
# Pertama, kita akan mengevaluasi **akurasi** pada dataset pelatihan.

# %% [markdown]
# ![image.png](attachment:8724b129-050f-42dc-9da7-a659aeaf4ca5.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

gnb.score(train_X, train_Y)
acc = round(gnb.score(train_X, train_Y)* 100, 2)
print("Naive Bayes accuracy (train set):", acc)
# Out:
# Naive Bayes accuracy (train set): 86.67

# %% [markdown]
# Hasil ini menunjukkan bahwa jumlah total prediksi yang benar dibagi dengan jumlah total contoh dalam dataset pelatihan adalah **100%**.
#
# Selanjutnya, kita akan mengevaluasi **akurasi** pada dataset validasi.

# %% [markdown]
# ![image.png](attachment:4491eef1-6af4-4c83-90bb-7bf82230bf32.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
gnb.score(valid_X, valid_Y)
acc = round(gnb.score(valid_X, valid_Y) * 100, 2)
print("Naive Bayes accuracy (validation set):", acc)
# Out:
# Naive Bayes accuracy (validation set): 85.67

# %% [markdown]
# Akurasi pada dataset pelatihan jauh lebih tinggi dibandingkan dengan akurasi pada dataset validasi.

# %% [markdown]
# ## <a id='svm'>SVM</a>
#
# **Support Vector Machine (SVM)** adalah algoritma **machine learning** yang digunakan untuk **klasifikasi** dan **regresi**.
# Dalam klasifikasi, SVM bekerja dengan mencari **hyperplane optimal** yang memisahkan kelas-kelas dalam suatu dataset dengan **margin terbesar**.

# %% [markdown]
# ![image.png](attachment:f180e063-cb99-4f83-b03a-b901ee63a027.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
from sklearn.svm import SVC

# Inisialisasi model SVM
svm = SVC(kernel='rbf', C=1.0, gamma='scale') #Anda dapat menyesuaikan kernel, C, dan gamma

#Latih model
svm.fit(train_X, train_Y)

#Lakukan prediksi
pred = svm.predict(valid_X)

#Hitung akurasi pada dataset pelatihan
train_acc = round(svm.score(train_X, train_Y) * 1000, 2)
print("Akurasi SVM (dataset pelatihan):", train_acc)

#Hitung akurasi pada dataset validasi
valid_acc = round(svm.score(valid_X, valid_Y) * 1000, 2)
print("Akurasi SVM (dataset validasi):", valid_acc)
# Out:
# Akurasi SVM (dataset pelatihan): 329.73
# Akurasi SVM (dataset validasi): 328.57

# %% [markdown]
# ## <a id='knn'>KNN</a>
#
# **K-Nearest Neighbors (KNN)** dapat diibaratkan seperti mencari teman yang paling mirip dengan Anda.
# Ketika perlu membuat keputusan (misalnya, menentukan kelas suatu data), algoritma ini melihat **'k' tetangga terdekat** di sekitarnya.
#
# Keputusan akhir ditentukan berdasarkan mayoritas kelas dari tetangga-tetangga tersebut.
# Sebagai contoh, jika sebagian besar tetangga terdekat Anda adalah **kucing**, maka kemungkinan besar Anda juga **kucing**.

# %% [markdown]
# ![image.png](attachment:05c01836-db01-42b4-b3d3-c81c263baacc.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, weights= 'uniform', metric='minkowski')
knn.fit(train_X, train_Y)
pred = knn.predict(valid_X)

knn.score(train_X, train_Y)
acc = round(knn.score(train_X, train_Y) * 100, 2)
print("KNN accuracy (train set):", acc)

knn.score(valid_X, valid_Y)
acc = round(knn.score(valid_X, valid_Y) * 100, 2)
print("KNN accuracy (validation set):", acc)
# Out:
# KNN accuracy (train set): 85.06
# KNN accuracy (validation set): 76.02

# %% [markdown]
# Akurasi pada data pelatihan jauh lebih tinggi dibandingkan dengan akurasi pada dataset validasi.
# Model terlalu **baik dalam menghafal** data pelatihan, yang berarti kita mengalami **overfitting**.

# %% [markdown]
# # <a id='submission'>Buat Pengajuan (Submission)</a>

# %% [markdown]
# ![image.png](attachment:cbf3f75b-a615-4028-a0ca-00d33d145c20.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
sample_submission = pd.read_csv("/content/sample_submission.csv")
submission = svm.predict(test)
sample_submission['Weather Type'] = submission

# %% [markdown]
# ![image.png](attachment:180dd521-099a-43b0-b0df-14745f530da5.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan
type_mapping = {0.0: 'Cloudy', 1.0:'Rainy', 2.0:'Snowy', 3.0: 'Sunny'}
#Map the values in the "Weather Type" column using the directory
sample_submission['Weather Type'] = sample_submission['Weather Type'].map(type_mapping)
sample_submission
# Out:
#          ID Weather Type
# 0      9240        Snowy
# 1      9241        Snowy
# 2      9242        Snowy
# 3      9243        Snowy
# 4      9244        Snowy
# ...     ...          ...
# 3955  13195        Rainy
# 3956  13196        Rainy
# 3957  13197        Rainy
# 3958  13198        Rainy
# 3959  13199        Rainy
#
# [3960 rows x 2 columns]

# %% [markdown]
# ![image.png](attachment:aa33f902-e289-43b3-b2f4-93cb19c3669e.png)

# %%
# Tulis kode di atas pada bagian kode berikut dan jalankan

sample_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# Kirim hasil prediksi ke kompetisi dengan mengklik tab **Submit to Competition** di sebelah kanan layar.
# Kemudian, klik tombol **Submit**.
#
# Untuk melihat hasilnya, buka tab **Leaderboard** pada halaman kompetisi:
# [Leaderboard Kaggle](https://www.kaggle.com/competitions/ir-klasifikasi-jenis-cuaca/leaderboard)
#
# Atau
#
# Klik tab **Output** di sebelah kanan layar.
# Lalu, klik kanan pada tiga titik vertikal di file **CSV**, pilih **More actions**, dan klik tombol **Download**.
#
# Untuk mengirim hasil ke **leaderboard**, buka halaman kompetisi:
# [https://bit.ly/ir-klasifikasi](https://bit.ly/ir-klasifikasi)
# Kemudian, klik tombol **Submit Prediction** di pojok kanan atas.
#
# Unggah file **CSV**, dan Anda telah berhasil mengirimkan hasil ke kompetisi! 🚀

# %% [markdown]
# # Cara Meningkatkan Skor

# %% [markdown]
# ## Optimasi Hyperparameter

# %% [markdown]
# ### Mengatur var_smoothing pada Naive Bayes

# %% [markdown]
# Hyperparameter var_smoothing dalam GaussianNB mengontrol jumlah varians tambahan yang ditambahkan ke setiap fitur untuk menghindari pembagian dengan nol. Range optimal = 1e-12 hingga 1e-3, tergantung pada dataset.

# %%
# from sklearn.naive_bayes import GaussianNB

# gnb = GaussianNB(var_smoothing=1e-3)

# %% [markdown]
# ### Mengatur kernel, C, dan gamma pada SVM

# %% [markdown]
# Kernel dalam SVM adalah fungsi yang mengubah data input menjadi ruang dimensi yang lebih tinggi untuk membuat data lebih mudah dipisahkan secara linear.
# Pilihan kernel = {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

# %% [markdown]
# gamma adalah hyperparameter yang mengontrol seberapa jauh pengaruh satu titik data terhadap titik data lain dalam kernel Radial Basis Function (RBF) dan Polynomial.
# Pilihan gamma{‘scale’, ‘auto’}

# %% [markdown]
# Hyperparameter C dalam Support Vector Machine (SVM) mengontrol keseimbangan antara margin yang lebih besar (generalisasi lebih baik) dan kesalahan klasifikasi yang lebih sedikit (overfitting). Nilai C dapat dicoba antara rentang 0.001-1000.

# %%
# svm = SVC(kernel='rbf', C=1.0, gamma='scale')

# %% [markdown]
# ### Mengatur n_neighbors, weights, dan metric pada KNN

# %% [markdown]
# n_neighbors menentukan jumlah tetangga terdekat yang akan digunakan dalam klasifikasi atau regresi.

# %% [markdown]
# weights menentukan bagaimana bobot diberikan ke tetangga dalam perhitungan keputusan.

# %% [markdown]
# metric menentukan bagaimana jarak antara titik data dihitung.

# %%
# knn = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric='minkowski')
